# %%
import keras

# %%
model = keras.models.load_model('saved_model_latest/LSTM')

# Check its architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50)                23400
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 23,451
# Trainable params: 23,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
import cv2
import mediapipe as mp
import numpy as np

# %%
mpPose = mp.solutions.pose
pose = mpPose.Pose()
mpDraw = mp.solutions.drawing_utils # For drawing keypoints
points = mpPose.PoseLandmark # Landmarks

# %%
def getarray(landmark): 
  r=[]
  for i in landmark:
    r.append([i.x,i.y])
  r=np.array(r)
  r=r.flatten()
  return r

# %%
def test(path):
  cap = cv2.VideoCapture(path)
  total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
  print(total_frames)
  arr=[]
  for fno in range(0, total_frames,1):
    print(f"frame number is{fno}")
    #print(fno)
    cap.set(cv2.CAP_PROP_POS_FRAMES, fno)
    _, image = cap.read()
    img = image.copy()
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = pose.process(imgRGB)
    landmark=results.pose_landmarks.landmark
    r=getarray(landmark)
    #print(r)
    if(fno<14):
      arr.append(r)
    elif(fno==14):
      arr.append(r)
      k=np.array(arr).reshape(-1,15,66)
      print(model.predict(k)[0])
    else:
      del arr[0]
      arr.append(r)
      k=np.array(arr).reshape(-1,15,66)
      p=model.predict(k)[0][0]
#       if((fno+1)%30==0):
      p=round(p,2)
      p=str(p)
      print(p)
      cv2.putText(image, p, (500,50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), thickness = 3)
      cv2.imshow('test',image)
      if cv2.waitKey(10) & 0xFF==ord('q'):
          break
    #out.write(image)

  cap.release()
  cv2.destroyAllWindows()

# %%
test("D:/Capstone/test/preetam saha not crossing the road.mp4")
# Out:
# 396
# frame number is0
# frame number is1
# frame number is2
# frame number is3
# frame number is4
# frame number is5
# frame number is6
# frame number is7
# frame number is8
# frame number is9
# frame number is10
# frame number is11
# frame number is12
# frame number is13
# frame number is14
# [0.14836049]
# frame number is15
# 0.15
# frame number is16
# 0.14
# frame number is17
# 0.14
# frame number is18
# 0.14
# frame number is19
# 0.14
# frame number is20
# 0.14
# frame number is21
# 0.14
# frame number is22
# 0.14
# frame number is23
# 0.14
# frame number is24
# 0.14
# frame number is25
# 0.14
# frame number is26
# 0.14
# frame number is27
# 0.14
# frame number is28
# 0.14
# frame number is29
# 0.14
# frame number is30
# 0.14
# frame number is31
# 0.14
# frame number is32
# 0.14
# frame number is33
# 0.14
# frame number is34
# 0.14
# frame number is35
# 0.14
# frame number is36
# 0.14
# frame number is37
# 0.14
# frame number is38
# 0.14
# frame number is39
# 0.14
# frame number is40
# 0.14
# frame number is41
# 0.14
# frame number is42
# 0.14
# frame number is43
# 0.14

# %%
# Import the required Libraries
from tkinter import *
from tkinter import ttk, filedialog
from tkinter.filedialog import askopenfile
import os

# Create an instance of tkinter frame
win = Tk()

# Set the geometry of tkinter frame
win.geometry("700x350")

def open_file():
   file = filedialog.askopenfile()
   if file:
      filepath = os.path.abspath(file.name)
      test(filepath)

# Add a Label widget
label = Label(win, text="Click the Button to browse the Files", font=('Georgia 13'))
label.pack(pady=10)

# Create a Button
ttk.Button(win, text="Browse", command=open_file).pack(pady=20)

win.mainloop()
# Out:
# 320
# frame number is0
# frame number is1
# frame number is2
# frame number is3
# frame number is4
# frame number is5
# frame number is6
# frame number is7
# frame number is8
# frame number is9
# frame number is10
# frame number is11
# frame number is12
# frame number is13
# frame number is14
# [0.08899125]
# frame number is15
# 0.09
# frame number is16
# 0.09
# frame number is17
# 0.1
# frame number is18
# 0.1
# frame number is19
# 0.1
# frame number is20
# 0.1
# frame number is21
# 0.1
# frame number is22
# 0.1
# frame number is23
# 0.09
# frame number is24
# 0.09
# frame number is25
# 0.09
# frame number is26
# 0.08
# frame number is27
# 0.08
# frame number is28
# 0.08
# frame number is29
# 0.08
# frame number is30
# 0.08
# frame number is31
# 0.08
# frame number is32
# 0.08
# frame number is33
# 0.08
# frame number is34
# 0.08
# frame number is35
# 0.08
# frame number is36
# 0.08
# frame number is37
# 0.07
# frame number is38
# 0.07
# frame number is39
# 0.07
# frame number is40
# 0.07
# frame number is41
# 0.07
# frame number is42
# 0.07
# frame number is43
# 0.08
# frame number is44
# 0.08
# frame number is45
# 0.08
# frame number is46
# 0.08
# frame number is47
# 0.08
# frame number is48
# 0.08
# frame number is49
# 0.08
# frame number is50
# 0.08
# frame number is51
# 0.08
# frame number is52
# 0.08
# frame number is53
# 0.08
# frame number is54
# 0.08
# frame number is55
# 0.08
# frame number is56
# 0.08
# frame number is57
# 0.08
# frame number is58
# 0.08
# frame number is59
# 0.08
# frame number is60
# 0.08
# frame number is61
# 0.08
# frame number is62
# 0.08
# frame number is63
# 0.08
# frame number is64
# 0.08
# frame number is65
# 0.08
# frame number is66
# 0.08
# frame number is67
# 0.08
# frame number is68
# 0.08
# frame number is69
# 0.08
# frame number is70
# 0.08
# frame number is71
# 0.08
# frame number is72
# 0.08
# frame number is73
# 0.08
# frame number is74
# 0.08
# frame number is75
# 0.08
# frame number is76
# 0.08
# frame number is77
# 0.08
# frame number is78
# 0.08
# frame number is79
# 0.08
# frame number is80
# 0.08
# frame number is81
# 0.08
# frame number is82
# 0.08
# frame number is83
# 0.08
# frame number is84
# 0.08
# frame number is85
# 0.08
# frame number is86
# 0.08
# frame number is87
# 0.08
# frame number is88
# 0.08
# frame number is89
# 0.08
# frame number is90
# 0.08
# frame number is91
# 0.08
# frame number is92
# 0.08
# frame number is93
# 0.08
# frame number is94
# 0.08
# frame number is95
# 0.08
# frame number is96
# 0.08
# frame number is97
# 0.08
# frame number is98
# 0.08
# frame number is99
# 0.09
# frame number is100
# 0.09
# frame number is101
# 0.09
# frame number is102
# 0.09
# frame number is103
# 0.09
# frame number is104
# 0.1
# frame number is105
# 0.1
# frame number is106
# 0.1
# frame number is107
# 0.1
# frame number is108
# 0.1
# frame number is109
# 0.11
# frame number is110
# 0.11
# frame number is111
# 0.11
# frame number is112
# 0.12
# frame number is113
# 0.12
# frame number is114
# 0.12
# frame number is115
# 0.13
# frame number is116
# 0.13
# frame number is117
# 0.13
# frame number is118
# 0.13
# frame number is119
# 0.14
# frame number is120
# 0.14
# frame number is121
# 0.14
# frame number is122
# 0.15
# frame number is123
# 0.16
# frame number is124
# 0.16
# frame number is125
# 0.17
# frame number is126
# 0.18
# frame number is127
# 0.2
# frame number is128
# 0.22
# frame number is129
# 0.25
# frame number is130
# 0.29
# frame number is131
# 0.33
# frame number is132
# 0.38
# frame number is133
# 0.45
# frame number is134
# 0.52
# frame number is135
# 0.58
# frame number is136
# 0.64
# frame number is137
# 0.68
# frame number is138
# 0.71
# frame number is139
# 0.73
# frame number is140
# 0.75
# frame number is141
# 0.76
# frame number is142
# 0.77
# frame number is143
# 0.78
# frame number is144
# 0.79
# frame number is145
# 0.79
# frame number is146
# 0.8
# frame number is147
# 0.8
# frame number is148
# 0.81
# frame number is149
# 0.81
# frame number is150
# 0.82
# frame number is151
# 0.82
# frame number is152
# 0.82
# frame number is153
# 0.83
# frame number is154
# 0.83
# frame number is155
# 0.83
# frame number is156
# 0.83
# frame number is157
# 0.83
# frame number is158
# 0.83
# frame number is159
# 0.83
# frame number is160
# 0.83
# frame number is161
# 0.83
# frame number is162
# 0.83
# frame number is163
# 0.83
# frame number is164
# 0.83
# frame number is165
# 0.83
# frame number is166
# 0.83
# frame number is167
# 0.83
# frame number is168
# 0.83
# frame number is169
# 0.82
# frame number is170
# 0.82
# frame number is171
# 0.82
# frame number is172
# 0.82
# frame number is173
# 0.82
# frame number is174
# 0.83
# frame number is175
# 0.83
# frame number is176
# 0.83
# frame number is177
# 0.83
# frame number is178
# 0.83
# frame number is179
# 0.83
# frame number is180
# 0.83
# frame number is181
# 0.84
# frame number is182
# 0.84
# frame number is183
# 0.84
# frame number is184
# 0.84
# frame number is185
# 0.84
# frame number is186
# 0.85
# frame number is187
# 0.85
# frame number is188
# 0.85
# frame number is189
# 0.85
# frame number is190
# 0.85
# frame number is191
# 0.85
# frame number is192
# 0.85
# frame number is193
# 0.85
# frame number is194
# 0.86
# frame number is195
# 0.86
# frame number is196
# 0.86
# frame number is197
# 0.86
# frame number is198
# 0.86
# frame number is199
# 0.86
# frame number is200
# 0.86
# frame number is201
# 0.86
# frame number is202
# 0.86
# frame number is203
# 0.86
# frame number is204
# 0.86
# frame number is205
# 0.86
# frame number is206
# 0.86
# frame number is207
# 0.86
# frame number is208
# 0.86
# frame number is209
# 0.86
# frame number is210
# 0.86
# frame number is211
# 0.86
# frame number is212
# 0.87
# frame number is213
# 0.87
# frame number is214
# 0.87
# frame number is215
# 0.87
# frame number is216
# 0.87
# frame number is217
# 0.87
# frame number is218
# 0.87
# frame number is219
# 0.87
# frame number is220
# 0.87
# frame number is221
# 0.87
# frame number is222
# 0.87
# frame number is223
# 0.87
# frame number is224
# 0.87
# frame number is225
# 0.87
# frame number is226
# 0.87
# frame number is227
# 0.87
# frame number is228
# 0.87
# frame number is229
# 0.87
# frame number is230
# 0.87
# frame number is231
# 0.87
# frame number is232
# 0.88
# frame number is233
# 0.88
# frame number is234
# 0.88
# frame number is235
# 0.88
# frame number is236
# 0.88
# frame number is237
# 0.88
# frame number is238
# 0.88
# frame number is239
# 0.88
# frame number is240
# 0.88
# frame number is241
# 0.88
# frame number is242
# 0.88
# frame number is243
# 0.88
# frame number is244
# 0.88
# frame number is245
# 0.88
# frame number is246
# 0.88
# frame number is247
# 0.88
# frame number is248
# 0.88
# frame number is249
# 0.88
# frame number is250
# 0.88
# frame number is251
# 0.88
# frame number is252
# 0.88
# frame number is253
# 0.88
# frame number is254
# 0.88
# frame number is255
# 0.88
# frame number is256
# 0.88
# frame number is257
# 0.88
# frame number is258
# 0.88
# frame number is259
# 0.88
# frame number is260
# 0.88
# frame number is261
# 0.88
# frame number is262
# 0.88
# frame number is263
# 0.88
# frame number is264
# 0.88
# frame number is265
# 0.88
# frame number is266
# 0.88
# frame number is267
# 0.88
# frame number is268
# 0.88
# frame number is269
# 0.88
# frame number is270
# 0.88
# frame number is271
# 0.88
# frame number is272
# 0.88
# frame number is273
# 0.88
# frame number is274
# 0.88
# frame number is275
# 0.88
# frame number is276
# 0.88
# frame number is277
# 0.88
# frame number is278
# 0.88
# frame number is279
# 0.88
# frame number is280
# 0.88
# frame number is281
# 0.88
# frame number is282
# 0.88
# frame number is283
# 0.88
# frame number is284
# 0.88
# frame number is285
# 0.88
# frame number is286
# 0.88
# frame number is287
# 0.88
# frame number is288
# 0.88
# frame number is289
# 0.88
# frame number is290
# 0.88
# frame number is291
# 0.88
# frame number is292
# 0.88
# frame number is293
# 0.88
# frame number is294
# 0.88
# frame number is295
# 0.88
# frame number is296
# 0.88
# frame number is297
# 0.88
# frame number is298
# 0.88
# frame number is299
# 0.88
# frame number is300
# 0.88
# frame number is301
# 0.88
# frame number is302
# 0.88
# frame number is303
# 0.88
# frame number is304
# 0.88
# frame number is305
# 0.88
# frame number is306
# 0.88
# frame number is307
# 0.88
# frame number is308
# 0.88
# frame number is309
# 0.88
# frame number is310
# 0.88
# frame number is311
# 0.88
# frame number is312
# 0.88
# frame number is313
# 0.88
# frame number is314
# 0.88
# frame number is315
# 0.88
# frame number is316
# 0.88
# frame number is317
# 0.88
# frame number is318
# 0.88
# frame number is319
# 0.88
# 396
# frame number is0
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Anaconda\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Navam Pradhan\AppData\Local\Temp\ipykernel_22400\2234665384.py", line 17, in open_file
#     test(filepath)
#   File "C:\Users\Navam Pradhan\AppData\Local\Temp\ipykernel_22400\786555784.py", line 14, in test
#     landmark=results.pose_landmarks.landmark
# AttributeError: 'NoneType' object has no attribute 'landmark'
